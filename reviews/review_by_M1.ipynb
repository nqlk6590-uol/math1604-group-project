# %% [markdown]
# # Code Review by M1
#
# ## Testing Instructions
# Run other team members' scripts and check if the cleaned dataset is generated correctly in the output folder.
#
# Example command:
# `python scripts/data_cleaning_M2.py`

# %% [markdown]
# ## Review of Team Member 2
# The script downloads the dataset correctly and saves it into the data folder. The code structure is clear and easy to follow. The solution works correctly and generates the cleaned dataset. Adding more comments could improve readability.

# %% [markdown]
# ## Review of Team Member 3
# The implementation standardizes the date format correctly. The script processes the dataset efficiently and produces the correct output file. Some variable names could be clearer to improve understanding.

# %% [markdown]
# ## Review of Team Member 4
# The script correctly identifies the date column and converts it to the required format. The workflow from reading the dataset to saving the cleaned data is logical and effective. Additional documentation would further improve the solution.
